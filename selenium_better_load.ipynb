# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver


options = Options()
options.add_experimental_option("detach",True)

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),
                          options=options)
driver.get("https://www.happycow.net/reviews/double-zero-baltimore-240250")

# %%
import pandas as pd

# %%
reviews = driver.find_elements(By.CLASS_NAME,'relative')
#reviews = driver.find_elements(By.XPATH,'//*[@id="full-site-content"]/div[3]/div[2]/div/div[2]/div[4]')
for review in reviews:
    star = review.find_element(By.XPATH,'//*[@id="1278880"]/div/div[3]/header/div').text
    date = review.find_element(By.XPATH,'//*[@id="1157565"]/div/div[3]/header/div/span').text
    review = review.find_element(By.XPATH,'//*[@id="1157565"]/div/div[3]/div[1]/div[1]/p').text
    print(star,date,review)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 reviews = driver.find_elements(By.CLASS_NAME,'relative')
#       2 #reviews = driver.find_elements(By.XPATH,'//*[@id="full-site-content"]/div[3]/div[2]/div/div[2]/div[4]')
#       3 for review in reviews:
#
# NameError: name 'driver' is not defined

# %%
reviews = driver.find_elements(By.CLASS_NAME,'relative')
#reviews = driver.find_elements(By.XPATH,'//*[@id="full-site-content"]/div[3]/div[2]/div/div[2]/div[4]')
for review in reviews:
    star = review.find_element(By.XPATH,'//*[@id="1278880"]/div/div[3]/header/div').text
    date = review.find_element(By.XPATH,'//*[@id="1157565"]/div/div[3]/header/div/span').text
    review = review.find_element(By.XPATH,'//*[@id="1157565"]/div/div[3]/div[1]/div[1]/p').text
    print(star,date,review)
# Out:
# 09 Mar 2023 26 Sep 2022 I’m literally blown away by how good this food was. We ordered the truffle pizza, cacio e pepe and eggplant parmesan and I swear their macadamia ricotta cheese is so creamy any omnivore would never be able to tell it was vegan! Will definitely be back
# 09 Mar 2023 26 Sep 2022 I’m literally blown away by how good this food was. We ordered the truffle pizza, cacio e pepe and eggplant parmesan and I swear their macadamia ricotta cheese is so creamy any omnivore would never be able to tell it was vegan! Will definitely be back
# 09 Mar 2023 26 Sep 2022 I’m literally blown away by how good this food was. We ordered the truffle pizza, cacio e pepe and eggplant parmesan and I swear their macadamia ricotta cheese is so creamy any omnivore would never be able to tell it was vegan! Will definitely be back
# ...
